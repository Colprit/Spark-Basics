# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /opt/conda/lib/python3.8/site-packages (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests) (1.26.3)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests) (2.10)

# %%
import requests
import json

# %% [markdown]
# #### Simple function to assemble API get requests for Highways API

# %%
def build_url(
    api_url = 'http://webtris.highwaysengland.co.uk/api/v1.0/',
    endpoint = 'reports/daily',
    query_params = {}
):
    query_params_str = '&'.join([f'{k}={v}' for k, v in query_params.items()])

    request_url = f'{api_url}/{endpoint}?{query_params_str}'

    return request_url

# %%
def get_request(url):

    response = requests.get(url)
    
    response_json = json.loads(response.text)

    return response_json

# %% [markdown]
# #### Get site data

# %%
query_params = {}

request_url = build_url(
    endpoint='sites/1',
    query_params=query_params
)

response_json = get_request(request_url)

print(json.dumps(response_json, indent=4))
# Out:
# {
#     "row_count": 1,
#     "sites": [
#         {
#             "Id": "1",
#             "Name": "MIDAS site at M4/2295A2 priority 1 on link 105009001; GPS Ref: 502816;178156; Westbound",
#             "Description": "M4/2295A2",
#             "Longitude": -0.520379557723297,
#             "Latitude": 51.4930115367112,
#             "Status": "Inactive"
#         }
#     ]
# }

# %% [markdown]
# #### Get report data

# %%
query_params = {
    'sites': 8188,
    'start_date': 31032016,
    'end_date': 31032017,
    'page': 1,
    'page_size': 50
}

request_url = build_url(query_params=query_params)

response_json = get_request(request_url)

print(json.dumps(response_json, indent=4))
# Out:
# {
#     "Header": {
#         "row_count": 31680,
#         "start_date": "31032016",
#         "end_date": "31032017",
#         "links": [
#             {
#                 "href": "http://webtris.highwaysengland.co.uk/api/v1.0/reports/Daily?sites=8188&start_date=31032016&end_date=31032017&page=2&page_size=50",
#                 "rel": "nextPage"
#             }
#         ]
#     },
#     "Rows": [
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "00:14:00",
#             "Time Interval": "0",
#             "0 - 520 cm": "12",
#             "521 - 660 cm": "0",
#             "661 - 1160 cm": "2",
#             "1160+ cm": "3",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "67",
#             "Total Volume": "17"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "00:29:00",
#             "Time Interval": "1",
#             "0 - 520 cm": "2",
#             "521 - 660 cm": "1",
#             "661 - 1160 cm": "0",
#             "1160+ cm": "4",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "58",
#             "Total Volume": "7"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "00:44:00",
#             "Time Interval": "2",
#             "0 - 520 cm": "2",
#             "521 - 660 cm": "1",
#             "661 - 1160 cm": "1",
#             "1160+ cm": "3",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "62",
#             "Total Volume": "7"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "00:59:00",
#             "Time Interval": "3",
#             "0 - 520 cm": "5",
#             "521 - 660 cm": "1",
#             "661 - 1160 cm": "2",
#             "1160+ cm": "3",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "62",
#             "Total Volume": "11"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "01:14:00",
#             "Time Interval": "4",
#             "0 - 520 cm": "4",
#             "521 - 660 cm": "0",
#             "661 - 1160 cm": "0",
#             "1160+ cm": "3",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "61",
#             "Total Volume": "7"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "01:29:00",
#             "Time Interval": "5",
#             "0 - 520 cm": "4",
#             "521 - 660 cm": "0",
#             "661 - 1160 cm": "2",
#             "1160+ cm": "3",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "59",
#             "Total Volume": "9"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "01:44:00",
#             "Time Interval": "6",
#             "0 - 520 cm": "1",
#             "521 - 660 cm": "0",
#             "661 - 1160 cm": "0",
#             "1160+ cm": "5",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "56",
#             "Total Volume": "6"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "01:59:00",
#             "Time Interval": "7",
#             "0 - 520 cm": "2",
#             "521 - 660 cm": "0",
#             "661 - 1160 cm": "1",
#             "1160+ cm": "2",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "61",
#             "Total Volume": "5"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "02:14:00",
#             "Time Interval": "8",
#             "0 - 520 cm": "2",
#             "521 - 660 cm": "2",
#             "661 - 1160 cm": "1",
#             "1160+ cm": "6",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "56",
#             "Total Volume": "11"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "02:29:00",
#             "Time Interval": "9",
#             "0 - 520 cm": "2",
#             "521 - 660 cm": "2",
#             "661 - 1160 cm": "1",
#             "1160+ cm": "3",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "57",
#             "Total Volume": "8"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "02:44:00",
#             "Time Interval": "10",
#             "0 - 520 cm": "3",
#             "521 - 660 cm": "1",
#             "661 - 1160 cm": "1",
#             "1160+ cm": "3",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "60",
#             "Total Volume": "8"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "02:59:00",
#             "Time Interval": "11",
#             "0 - 520 cm": "4",
#             "521 - 660 cm": "0",
#             "661 - 1160 cm": "0",
#             "1160+ cm": "4",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "58",
#             "Total Volume": "8"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "03:14:00",
#             "Time Interval": "12",
#             "0 - 520 cm": "1",
#             "521 - 660 cm": "0",
#             "661 - 1160 cm": "1",
#             "1160+ cm": "2",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "52",
#             "Total Volume": "4"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "03:29:00",
#             "Time Interval": "13",
#             "0 - 520 cm": "0",
#             "521 - 660 cm": "0",
#             "661 - 1160 cm": "0",
#             "1160+ cm": "5",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "53",
#             "Total Volume": "5"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "03:44:00",
#             "Time Interval": "14",
#             "0 - 520 cm": "3",
#             "521 - 660 cm": "1",
#             "661 - 1160 cm": "2",
#             "1160+ cm": "2",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "58",
#             "Total Volume": "8"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "03:59:00",
#             "Time Interval": "15",
#             "0 - 520 cm": "2",
#             "521 - 660 cm": "1",
#             "661 - 1160 cm": "2",
#             "1160+ cm": "7",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "50",
#             "Total Volume": "12"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "04:14:00",
#             "Time Interval": "16",
#             "0 - 520 cm": "5",
#             "521 - 660 cm": "1",
#             "661 - 1160 cm": "0",
#             "1160+ cm": "4",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "64",
#             "Total Volume": "10"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "04:29:00",
#             "Time Interval": "17",
#             "0 - 520 cm": "6",
#             "521 - 660 cm": "1",
#             "661 - 1160 cm": "2",
#             "1160+ cm": "4",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "58",
#             "Total Volume": "13"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "04:44:00",
#             "Time Interval": "18",
#             "0 - 520 cm": "11",
#             "521 - 660 cm": "1",
#             "661 - 1160 cm": "3",
#             "1160+ cm": "4",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "63",
#             "Total Volume": "19"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "04:59:00",
#             "Time Interval": "19",
#             "0 - 520 cm": "14",
#             "521 - 660 cm": "1",
#             "661 - 1160 cm": "4",
#             "1160+ cm": "3",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "65",
#             "Total Volume": "22"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "05:14:00",
#             "Time Interval": "20",
#             "0 - 520 cm": "16",
#             "521 - 660 cm": "4",
#             "661 - 1160 cm": "6",
#             "1160+ cm": "6",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "64",
#             "Total Volume": "32"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "05:29:00",
#             "Time Interval": "21",
#             "0 - 520 cm": "34",
#             "521 - 660 cm": "4",
#             "661 - 1160 cm": "2",
#             "1160+ cm": "7",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "67",
#             "Total Volume": "47"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "05:44:00",
#             "Time Interval": "22",
#             "0 - 520 cm": "37",
#             "521 - 660 cm": "2",
#             "661 - 1160 cm": "4",
#             "1160+ cm": "7",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "66",
#             "Total Volume": "50"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "05:59:00",
#             "Time Interval": "23",
#             "0 - 520 cm": "31",
#             "521 - 660 cm": "3",
#             "661 - 1160 cm": "4",
#             "1160+ cm": "10",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "65",
#             "Total Volume": "48"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "06:14:00",
#             "Time Interval": "24",
#             "0 - 520 cm": "50",
#             "521 - 660 cm": "10",
#             "661 - 1160 cm": "2",
#             "1160+ cm": "7",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "67",
#             "Total Volume": "69"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "06:29:00",
#             "Time Interval": "25",
#             "0 - 520 cm": "85",
#             "521 - 660 cm": "6",
#             "661 - 1160 cm": "3",
#             "1160+ cm": "10",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "68",
#             "Total Volume": "104"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "06:43:00",
#             "Time Interval": "26",
#             "0 - 520 cm": "130",
#             "521 - 660 cm": "3",
#             "661 - 1160 cm": "8",
#             "1160+ cm": "17",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "69",
#             "Total Volume": "158"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "06:59:00",
#             "Time Interval": "27",
#             "0 - 520 cm": "171",
#             "521 - 660 cm": "13",
#             "661 - 1160 cm": "4",
#             "1160+ cm": "11",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "70",
#             "Total Volume": "199"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "07:14:00",
#             "Time Interval": "28",
#             "0 - 520 cm": "186",
#             "521 - 660 cm": "9",
#             "661 - 1160 cm": "10",
#             "1160+ cm": "9",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "71",
#             "Total Volume": "214"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "07:29:00",
#             "Time Interval": "29",
#             "0 - 520 cm": "188",
#             "521 - 660 cm": "4",
#             "661 - 1160 cm": "3",
#             "1160+ cm": "13",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "72",
#             "Total Volume": "208"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "07:44:00",
#             "Time Interval": "30",
#             "0 - 520 cm": "222",
#             "521 - 660 cm": "8",
#             "661 - 1160 cm": "11",
#             "1160+ cm": "7",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "72",
#             "Total Volume": "248"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "07:59:00",
#             "Time Interval": "31",
#             "0 - 520 cm": "245",
#             "521 - 660 cm": "12",
#             "661 - 1160 cm": "8",
#             "1160+ cm": "15",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "72",
#             "Total Volume": "280"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "08:14:00",
#             "Time Interval": "32",
#             "0 - 520 cm": "214",
#             "521 - 660 cm": "7",
#             "661 - 1160 cm": "3",
#             "1160+ cm": "9",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "71",
#             "Total Volume": "233"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "08:29:00",
#             "Time Interval": "33",
#             "0 - 520 cm": "236",
#             "521 - 660 cm": "10",
#             "661 - 1160 cm": "10",
#             "1160+ cm": "15",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "72",
#             "Total Volume": "271"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "08:44:00",
#             "Time Interval": "34",
#             "0 - 520 cm": "221",
#             "521 - 660 cm": "12",
#             "661 - 1160 cm": "15",
#             "1160+ cm": "9",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "71",
#             "Total Volume": "257"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "08:59:00",
#             "Time Interval": "35",
#             "0 - 520 cm": "165",
#             "521 - 660 cm": "12",
#             "661 - 1160 cm": "10",
#             "1160+ cm": "7",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "71",
#             "Total Volume": "194"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "09:14:00",
#             "Time Interval": "36",
#             "0 - 520 cm": "134",
#             "521 - 660 cm": "7",
#             "661 - 1160 cm": "9",
#             "1160+ cm": "14",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "69",
#             "Total Volume": "164"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "09:29:00",
#             "Time Interval": "37",
#             "0 - 520 cm": "148",
#             "521 - 660 cm": "14",
#             "661 - 1160 cm": "11",
#             "1160+ cm": "9",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "68",
#             "Total Volume": "182"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "09:44:00",
#             "Time Interval": "38",
#             "0 - 520 cm": "138",
#             "521 - 660 cm": "9",
#             "661 - 1160 cm": "8",
#             "1160+ cm": "12",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "68",
#             "Total Volume": "167"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "09:59:00",
#             "Time Interval": "39",
#             "0 - 520 cm": "156",
#             "521 - 660 cm": "8",
#             "661 - 1160 cm": "10",
#             "1160+ cm": "16",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "68",
#             "Total Volume": "190"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "10:14:00",
#             "Time Interval": "40",
#             "0 - 520 cm": "129",
#             "521 - 660 cm": "11",
#             "661 - 1160 cm": "8",
#             "1160+ cm": "13",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "68",
#             "Total Volume": "161"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "10:29:00",
#             "Time Interval": "41",
#             "0 - 520 cm": "119",
#             "521 - 660 cm": "5",
#             "661 - 1160 cm": "12",
#             "1160+ cm": "18",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "65",
#             "Total Volume": "154"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "10:44:00",
#             "Time Interval": "42",
#             "0 - 520 cm": "136",
#             "521 - 660 cm": "9",
#             "661 - 1160 cm": "12",
#             "1160+ cm": "21",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "65",
#             "Total Volume": "178"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "10:59:00",
#             "Time Interval": "43",
#             "0 - 520 cm": "129",
#             "521 - 660 cm": "13",
#             "661 - 1160 cm": "15",
#             "1160+ cm": "13",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "67",
#             "Total Volume": "170"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "11:14:00",
#             "Time Interval": "44",
#             "0 - 520 cm": "118",
#             "521 - 660 cm": "12",
#             "661 - 1160 cm": "15",
#             "1160+ cm": "15",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "66",
#             "Total Volume": "160"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "11:29:00",
#             "Time Interval": "45",
#             "0 - 520 cm": "125",
#             "521 - 660 cm": "10",
#             "661 - 1160 cm": "9",
#             "1160+ cm": "16",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "67",
#             "Total Volume": "160"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "11:44:00",
#             "Time Interval": "46",
#             "0 - 520 cm": "136",
#             "521 - 660 cm": "8",
#             "661 - 1160 cm": "15",
#             "1160+ cm": "10",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "65",
#             "Total Volume": "169"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "11:59:00",
#             "Time Interval": "47",
#             "0 - 520 cm": "159",
#             "521 - 660 cm": "7",
#             "661 - 1160 cm": "15",
#             "1160+ cm": "18",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "66",
#             "Total Volume": "199"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "12:14:00",
#             "Time Interval": "48",
#             "0 - 520 cm": "130",
#             "521 - 660 cm": "11",
#             "661 - 1160 cm": "11",
#             "1160+ cm": "6",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "67",
#             "Total Volume": "158"
#         },
#         {
#             "Site Name": "7001/1",
#             "Report Date": "2016-03-31T00:00:00",
#             "Time Period Ending": "12:29:00",
#             "Time Interval": "49",
#             "0 - 520 cm": "124",
#             "521 - 660 cm": "10",
#             "661 - 1160 cm": "10",
#             "1160+ cm": "13",
#             "0 - 10 mph": "",
#             "11 - 15 mph": "",
#             "16 - 20 mph": "",
#             "21 - 25 mph": "",
#             "26 - 30 mph": "",
#             "31 - 35 mph": "",
#             "36 - 40 mph": "",
#             "41 - 45 mph": "",
#             "46 - 50 mph": "",
#             "51 - 55 mph": "",
#             "56 - 60 mph": "",
#             "61 - 70 mph": "",
#             "71 - 80 mph": "",
#             "80+ mph": "",
#             "Avg mph": "66",
#             "Total Volume": "157"
#         }
#     ]
# }

# %% [markdown]
# #### API responses include links to previous and next pages of data, these can be used to automate pagination through them all

# %%
response_json['Header']['links'][0]['href']
# Out:
# 'http://webtris.highwaysengland.co.uk/api/v1.0/reports/Daily?sites=8188&start_date=31032016&end_date=31032017&page=2&page_size=50'

# %%
def get_next_url(response):
    
    header = response['Header']
    
    links = header['links']
    
    for link in links:
        
        if link['rel'] == 'nextPage':
            
            return link['href']
    
    return None

# %%
def get_all_pages(api_url):
    
    data = []
    
    next_url = api_url
    
    while next_url:
        
        print(next_url)
        
        response_json = get_request(next_url)

        next_url = get_next_url(response_json)

        data += response_json['Rows']
    
    return data

# %%
query_params = {
    'sites': 8188,
    'start_date': 31012020,
    'end_date':   31072020,
    'page': 1,
    'page_size': 50
}

request_url = build_url(query_params=query_params)

all_pages = get_all_pages(request_url)

# print(json.dumps(all_pages, indent=4))



filename = f"report_daily_{query_params['sites']}_{query_params['start_date']}_{query_params['end_date']}.json"

with open(filename, 'w') as f:
    
    json.dump(all_pages, f)
    
    print(f'written to file: {filename}')
# Out:
# http://webtris.highwaysengland.co.uk/api/v1.0//reports/daily?sites=8188&start_date=31012020&end_date=31072020&page=1&page_size=50
# http://webtris.highwaysengland.co.uk/api/v1.0/reports/Daily?sites=8188&start_date=31012020&end_date=31072020&page=2&page_size=50
# http://webtris.highwaysengland.co.uk/api/v1.0/reports/Daily?sites=8188&start_date=31012020&end_date=31072020&page=3&page_size=50
# http://webtris.highwaysengland.co.uk/api/v1.0/reports/Daily?sites=8188&start_date=31012020&end_date=31072020&page=4&page_size=50
# http://webtris.highwaysengland.co.uk/api/v1.0/reports/Daily?sites=8188&start_date=31012020&end_date=31072020&page=5&page_size=50
# http://webtris.highwaysengland.co.uk/api/v1.0/reports/Daily?sites=8188&start_date=31012020&end_date=31072020&page=6&page_size=50
# http://webtris.highwaysengland.co.uk/api/v1.0/reports/Daily?sites=8188&start_date=31012020&end_date=31072020&page=7&page_size=50
# http://webtris.highwaysengland.co.uk/api/v1.0/reports/Daily?sites=8188&start_date=31012020&end_date=31072020&page=8&page_size=50
# http://webtris.highwaysengland.co.uk/api/v1.0/reports/Daily?sites=8188&start_date=31012020&end_date=31072020&page=9&page_size=50
# http://webtris.highwaysengland.co.uk/api/v1.0/reports/Daily?sites=8188&start_date=31012020&end_date=31072020&page=10&page_size=50
# http://webtris.highwaysengland.co.uk/api/v1.0/reports/Daily?sites=8188&start_date=31012020&end_date=31072020&page=11&page_size=50
# http://webtris.highwaysengland.co.uk/api/v1.0/reports/Daily?sites=8188&start_date=31012020&end_date=31072020&page=12&page_size=50
# http://webtris.highwaysengland.co.uk/api/v1.0/reports/Daily?sites=8188&start_date=31012020&end_date=31072020&page=13&page_size=50
# http://webtris.highwaysengland.co.uk/api/v1.0/reports/Daily?sites=8188&start_date=31012020&end_date=31072020&page=14&page_size=50
# http://webtris.highwaysengland.co.uk/api/v1.0/reports/Daily?sites=8188&start_date=31012020&end_date=31072020&page=15&page_size=50
# http://webtris.highwaysengland.co.uk/api/v1.0/reports/Daily?sites=8188&start_date=31012020&end_date=31072020&page=16&page_size=50
# http://webtris.highwaysengland.co.uk/api/v1.0/reports/Daily?sites=8188&start_date=31012020&end_date=31072020&page=17&page_size=50
# http://webtris.highwaysengland.co.uk/api/v1.0/reports/Daily?sites=8188&start_date=31012020&end_date=31072020&page